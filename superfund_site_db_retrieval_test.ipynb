# %%
# Import dependencies
import pandas as pd
import requests
import time
import csv

# %%
state_abbrev = {'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR',
    'California': 'CA', 'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE',
    'District of Columbia': 'DC', 'Florida': 'FL', 'Georgia': 'GA', 'Guam': 'GU', 
    'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA',
    'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME',
    'Maryland': 'MD', 'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN',
    'Mississippi': 'MS', 'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV',
    'New Hampshire': 'NH', 'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY',
    'North Carolina': 'NC', 'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR',
    'Pennsylvania': 'PA', 'Puerto Rico': 'PR', 'Rhode Island': 'RI', 'South Carolina': 'SC',
    'South Dakota': 'SD', 'Tennessee': 'TN', 'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT',
    'Virginia': 'VA', 'Washington': 'WA', 'West Virginia': 'WV', 'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
states = list(state_abbrev.values())

# %%
# API request for each ACTIVE site by State ID, then append into one DataFrame. 
# Notes:
# 1) multiple attempts were made to request the data in one lump without a loop; however, they either did not 
# return any data, or were prohibitively slow
# 2) EPA includes some inactive site in the Active table in their DataBase; will be cleaned at later stage. 
x = 0
for state in states:
    try:
        request = requests.get(f'https://data.epa.gov/efservice/SEMS_ACTIVE_SITES/SITE_STATE/CONTAINING/{state}/JSON').json()
        temp_df = pd.DataFrame(request)
        if x == 0:
            sf_active_df = temp_df.copy()
            print(f'{state} added to DataFrame')
            x = 1
        else:
            sf_active_df = pd.concat([sf_active_df, temp_df])
            print(f'{state} added to DataFrame')
    except Exception:
        print(Exception)
        print(f'Exception occurred on {state}')
print('----------------------\n\
Data download complete \n\
----------------------')
# Out:
# AL added to DataFrame
# AK added to DataFrame
# AZ added to DataFrame
# AR added to DataFrame
# CA added to DataFrame
# CO added to DataFrame
# CT added to DataFrame
# DE added to DataFrame
# DC added to DataFrame
# FL added to DataFrame
# GA added to DataFrame
# GU added to DataFrame
# HI added to DataFrame
# ID added to DataFrame
# IL added to DataFrame
# IN added to DataFrame
# IA added to DataFrame
# KS added to DataFrame
# KY added to DataFrame
# LA added to DataFrame
# ME added to DataFrame
# MD added to DataFrame
# MA added to DataFrame
# MI added to DataFrame
# MN added to DataFrame
# MS added to DataFrame
# MO added to DataFrame
# MT added to DataFrame
# NE added to DataFrame
# NV added to DataFrame
# NH added to DataFrame
# NJ added to DataFrame
# NM added to DataFrame
# NY added to DataFrame
# NC added to DataFrame
# ND added to DataFrame
# OH added to DataFrame
# OK added to DataFrame
# OR added to DataFrame
# PA added to DataFrame
# PR added to DataFrame
# ...

# %%
sf_active_df
# Out:
#     RG  SITE_ID   SITE_EPA_ID                                       SITE_NAME  \
# 0    4  0406154  AL0000047829                               WEST END LANDFILL
# 1    4  0406158  AL0000059147             ETOWAH COUNTY (RIDGEVILLE) LANDFILL
# 2    4  0406176  AL0000132662                            FUSSY HILL DRUM DUMP
# 3    4  0406800  AL0000301747                                  JONES PROPERTY
# 4    4  0406321  AL0001024793                            ILCO SATELLITE SITES
# ..  ..      ...           ...                                             ...
# 36   8  0820977  WYN000820977                              HARTVILLE (TRONOX)
# 37   8  0820979  WYN000820979                       PETROTOMICS MILL (TRONOX)
# 38   8  0820999  WYN000820999                     THOMES AVENUE MERCURY SPILL
# 39   8  0821050  WYN000821050        YELLOWSTONE NATIONAL PARK GASOLINE SPILL
# 40   8  0801762  WY0009138800  WARREN F.E. AFB ATLAS %22D%22 MISSILE SITE # 1
#
# ...

# %%
states_debug = ['LA']

# %%
# API request for each ARCHIVED site by State ID, then append into one DataFrame. 
# Notes:
# 1) multiple attempts were made to request the data in one lump without a loop; however, they either did not 
# return any data, or were prohibitively slow
# 2) Runtime for this request is much slower than the ACTIVE site request. 
x = 0
for state in states_debug:
    try:
        request = requests.get(f'https://data.epa.gov/efservice/SEMS_ARCHIVED_SITES/SITE_STATE/CONTAINING/{state}/JSON').json()
        temp_df = pd.DataFrame(request)
        if x == 0:
            sf_archived_df = temp_df.copy()
            print(f'{state} added to DataFrame')
            x = 1
        else:
            sf_archived_df = pd.concat([sf_archived_df, temp_df])
            print(f'{state} added to DataFrame')
    except Exception:
        print(Exception)
        print(f'Exception occurred on {state}')
# Out:
# <class 'Exception'>
# Exception occurred on FL

# %%
exception_states = ('FL GA IA KS KY MD MA MN MO MT NE NJ NM NY ND OH PA PR RI SD TX').split()

# %%
x = 0
exception_states = []
for state in states:
    try:
        request = requests.get(f'https://data.epa.gov/efservice/SEMS_ARCHIVED_SITES/SITE_STATE/CONTAINING/{state}/CSV')
#         url_data = request.content
        temp_df = pd.DataFrame(request)
        if x == 0:
            sf_archived_df_csv = temp_df.copy()
            print(f'{state} added to DataFrame')
            x = 1
        else:
            sf_archived_df_csv = pd.concat([sf_archived_df, temp_df])
            print(f'{state} added to DataFrame')
    except Exception:
        print(Exception)
        print(f'Exception occurred on {state}')
        exception_states.append(state)
# Out:
# AL added to DataFrame
# AK added to DataFrame
# AZ added to DataFrame
# AR added to DataFrame
# CA added to DataFrame
# CO added to DataFrame
# CT added to DataFrame
# DE added to DataFrame
# DC added to DataFrame
# FL added to DataFrame
# GA added to DataFrame
# GU added to DataFrame
# HI added to DataFrame
# ID added to DataFrame
# IL added to DataFrame
# IN added to DataFrame
# IA added to DataFrame
# KS added to DataFrame
# KY added to DataFrame
# LA added to DataFrame
# ME added to DataFrame
# MD added to DataFrame
# MA added to DataFrame
# MI added to DataFrame
# MN added to DataFrame
# MS added to DataFrame
# MO added to DataFrame
# MT added to DataFrame
# NE added to DataFrame
# NV added to DataFrame
# NH added to DataFrame
# NJ added to DataFrame
# NM added to DataFrame
# NY added to DataFrame
# NC added to DataFrame
# ND added to DataFrame
# OH added to DataFrame
# OK added to DataFrame
# OR added to DataFrame
# PA added to DataFrame
# PR added to DataFrame
# ...

# %%
states_debug = ["FL"]

# %%
x = 0
for state in states_debug:
    try:
        request = requests.get(f'https://data.epa.gov/efservice/SEMS_ARCHIVED_SITES/SITE_STATE/CONTAINING/{state}/CSV').csv()
        print("Error1")
        csv_reader = csv.reader(request.splitlines(), delimiter=',')
        print("Error2")
        temp_df = pd.DataFrame(url_content)
        print("Error3")
        if x == 0:
            sf_archived_df = temp_df.copy()
            print(f'{state} added to DataFrame')
            x = 1
        else:
            sf_archived_df = pd.concat([sf_archived_df, temp_df])
            print(f'{state} added to DataFrame')
    except Exception:
        print(Exception)
        print(f'Exception occurred on {state}')
print('----------------------\n\
Data download complete \n\
----------------------')
# Out:
# <class 'Exception'>
# Exception occurred on AL
# ----------------------
# Data download complete
# ----------------------

# %%
x = 1
for state in states_debug:
    request = requests.get(f'https://data.epa.gov/efservice/SEMS_ARCHIVED_SITES/SITE_STATE/CONTAINING/{state}/CSV').csv()
    print("Error1")
    csv_reader = csv.reader(request.splitlines(), delimiter=',')
    print("Error2")
    temp_df = pd.DataFrame(url_content)
    print("Error3")
    if x == 0:
        sf_archived_df = temp_df.copy()
        print(f'{state} added to DataFrame')
        x = 1
    else:
        sf_archived_df = pd.concat([sf_archived_df, temp_df])
        print(f'{state} added to DataFrame')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-125-13ce7ad96d79> in <module>
#       1 x = 1
#       2 for state in states_debug:
# ----> 3     request = requests.get(f'https://data.epa.gov/efservice/SEMS_ARCHIVED_SITES/SITE_STATE/CONTAINING/{state}/CSV').csv()
#       4     print("Error1")
#       5     csv_reader = csv.reader(request.splitlines(), delimiter=',')
#
# AttributeError: 'Response' object has no attribute 'csv'

# %%
x = 1
for state in states_debug:
    request = requests.get(f'https://data.epa.gov/efservice/SEMS_ARCHIVED_SITES/SITE_STATE/CONTAINING/{state}/JSON').json()
    print("Error1")
    temp_df = pd.DataFrame(request)
    print("Error3")
    if x == 0:
        sf_archived_df = temp_df.copy()
        print(f'{state} added to DataFrame')
        x = 1
    else:
        sf_archived_df = pd.concat([sf_archived_df, temp_df])
        print(f'{state} added to DataFrame')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-127-b61583e7bc08> in <module>
#       1 x = 1
#       2 for state in states_debug:
# ----> 3     request = requests.get(f'https://data.epa.gov/efservice/SEMS_ARCHIVED_SITES/SITE_STATE/CONTAINING/{state}/JSON').json()
#       4     print("Error1")
#       5     temp_df = pd.DataFrame(request)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     888                 try:
#     889                     return complexjson.loads(
# --> 890                         self.content.decode(encoding), **kwargs
#     891                     )
#     892                 except UnicodeDecodeError:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
# ...

# %%
sf_archived_df
# Out:
#                                                      0
# 0    b'SEMS_ARCHIVED_SITES.RG,SEMS_ARCHIVED_SITES.S...
# 1    b'ITES.SITE_STRT_ADRS1,SEMS_ARCHIVED_SITES.SIT...
# 2    b'ARCHIVED_SITES.SITE_ZIP_CODE,SEMS_ARCHIVED_S...
# 3    b'FIPS_CODE,SEMS_ARCHIVED_SITES.ALT_AGREEMENT,...
# 4    b'MS_ARCHIVED_SITES.LATITUDE,SEMS_ARCHIVED_SIT...
# ..                                                 ...
# 813  b'"BAY BRIDGE RD US ROUTE 90","","MOBILE","AL"...
# 814  b'008150286","GULF PLATING COMPANY INC","406 S...
# 815  b'N","",""\n"4","0400143","ALD008150617","COUR...
# 816  b'Not on the NPL","N","N","",""\n"4","0400145"...
# 817  b'"36426","01","ESCAMBIA","01053","N","Not on ...
#
# [818 rows x 1 columns]

# %%
# Saves as .csv file
sf_active_df.to_csv('resources/superfund_sites.csv', index = False)

# %%
# Replaces "%26" with "&"; data from EPA Databases replaces "&" with "%26"
def replace_amp(string):
    return string.replace("%26", "&")

# %%
print('----------------------\n\
Data download complete \n\
----------------------')
# Out:
# ----------------------
# Data download complete
# ----------------------

# %%
sf_archived_df_csv2
# Out:
#                                                      0
# 0    b'SEMS_ARCHIVED_SITES.RG,SEMS_ARCHIVED_SITES.S...
# 1    b'ITES.SITE_STRT_ADRS1,SEMS_ARCHIVED_SITES.SIT...
# 2    b'ARCHIVED_SITES.SITE_ZIP_CODE,SEMS_ARCHIVED_S...
# 3    b'FIPS_CODE,SEMS_ARCHIVED_SITES.ALT_AGREEMENT,...
# 4    b'MS_ARCHIVED_SITES.LATITUDE,SEMS_ARCHIVED_SIT...
# ..                                                 ...
# 245  b'RCURY SPILL","115 SOUTH NICHOLS STREET","","...
# 246  b'8","0801681","WYSFN0801681","BLM-RAWLINS LAN...
# 247  b'","Not on the NPL","Y","Y","",""\n"8","08008...
# 248  b'"WY","82637","01","CONVERSE","56009","N","No...
# 249  b'I W OF RAWLINS","","TIPTON","WY","82301","01...
#
# [51879 rows x 1 columns]
